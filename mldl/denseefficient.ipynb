# %%
import os
import itertools
import cv2
import numpy as np 
import pandas as pd 
import seaborn as sn
import matplotlib.pyplot as plt
import tensorflow as tf
import warnings
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.applications import DenseNet201, EfficientNetB0, NASNetLarge ,Xception, ConvNeXtXLarge
from tensorflow.keras.applications import InceptionV3, InceptionResNetV2, VGG19, MobileNetV3Large
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Layer, Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout,BatchNormalization
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# 2025-03-03 15:40:24.124444: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-03 15:40:24.124595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-03 15:40:24.257629: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Make DataFrame

# %%
data_dir ="/kaggle/input/brain-tumor-mri-images-44c"
paths = []
labels = []
folds = os.listdir(data_dir)
for fold in folds :
    condition_path = os.path.join(data_dir,fold)
    all_pic = os.listdir(condition_path)
    for each_pic in all_pic:
        each_pic_path = os.path.join(condition_path,each_pic)
        paths.append(each_pic_path)
        labels.append(fold.split(' ')[0])
        
pseries = pd.Series(paths, name='Picture Path')
lseries = pd.Series(labels, name='Label')

df = pd.concat([pseries, lseries], axis =1)
df.head()
# Out:
#                                         Picture Path     Label
# 0  /kaggle/input/brain-tumor-mri-images-44c/Papil...  Papiloma
# 1  /kaggle/input/brain-tumor-mri-images-44c/Papil...  Papiloma
# 2  /kaggle/input/brain-tumor-mri-images-44c/Papil...  Papiloma
# 3  /kaggle/input/brain-tumor-mri-images-44c/Papil...  Papiloma
# 4  /kaggle/input/brain-tumor-mri-images-44c/Papil...  Papiloma

# %%
train_df, ts_df = train_test_split(df,test_size= 0.2,shuffle=True,random_state=42,stratify= df['Label'])
test_df, valid_df = train_test_split(ts_df,test_size= 0.5,shuffle=True,random_state=42,stratify= ts_df['Label'])

# %% [markdown]
# ## Image Data Generator

# %%
batch_size = 32
img_size = (224,224)
gen = ImageDataGenerator()

train_gen = gen.flow_from_dataframe(train_df, x_col='Picture Path', y_col='Label',target_size= img_size, 
                                   class_mode= 'categorical', color_mode='rgb', shuffle = True, batch_size= batch_size)

valid_gen = gen.flow_from_dataframe(valid_df, x_col='Picture Path', y_col='Label',target_size= img_size, 
                                   class_mode= 'categorical', color_mode='rgb', shuffle = True, batch_size= batch_size)

test_gen = gen.flow_from_dataframe(test_df, x_col='Picture Path', y_col='Label',target_size= img_size, 
                                   class_mode= 'categorical', color_mode='rgb', shuffle = False, batch_size= batch_size)
# Out:
# Found 3582 validated image filenames belonging to 15 classes.
# Found 448 validated image filenames belonging to 15 classes.
# Found 448 validated image filenames belonging to 15 classes.

# %%
g_dict = train_gen.class_indices
classes= list(g_dict.keys())
images, labels = next(train_gen)
plt.figure(figsize= (20,20))

for i in range (16):
    plt.subplot(4,4,i+1)
    image = images[i] / 255
    plt.imshow(image)
    index= np.argmax(labels[i])
    class_name = classes[index]
    plt.title(class_name,c='r', fontsize=12)
    plt.axis('off')
plt.show()

# %% [markdown]
# # Create Model Structure

# %%
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
class_count = len(list(train_gen.class_indices.keys()))

# %%
base_model = DenseNet201(include_top= False , weights= "imagenet", input_shape= img_shape, pooling= 'max')
densent = Sequential([
    base_model,
    Flatten(),
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(128, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])
densent.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', 
              metrics= ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

densent.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1920)              18321984
#
#  flatten (Flatten)           (None, 1920)              0
#
#  batch_normalization (Batch  (None, 1920)              7680
#  Normalization)
#
#  dense (Dense)               (None, 256)               491776
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 15)                1935
#
# =================================================================
# Total params: 18856271 (71.93 MB)
# Trainable params: 18623375 (71.04 MB)
# Non-trainable params: 232896 (909.75 KB)
# _________________________________________________________________

# %%
base_model = Xception(include_top= False , weights= "imagenet", input_shape= img_shape, pooling= 'max')
xcept = Sequential([
    base_model,
    Flatten(),
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(128, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])
xcept.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', 
              metrics= ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

xcept.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  batch_normalization_5 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense_3 (Dense)             (None, 256)               524544
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 15)                1935
#
# =================================================================
# Total params: 21429047 (81.75 MB)
# Trainable params: 21370423 (81.52 MB)
# Non-trainable params: 58624 (229.00 KB)
# _________________________________________________________________

# %%
base_model = MobileNetV3Large(include_top= False , weights= "imagenet", input_shape= img_shape, pooling= 'max')
mvl = Sequential([
    base_model,
    Flatten(),
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(128, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])
mvl.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', 
              metrics= ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

mvl.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Function  (None, 960)               2996352
#  al)
#
#  flatten_2 (Flatten)         (None, 960)               0
#
#  batch_normalization_6 (Bat  (None, 960)               3840
#  chNormalization)
#
#  dense_6 (Dense)             (None, 256)               246016
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 15)                1935
#
# =================================================================
# Total params: 3281039 (12.52 MB)
# Trainable params: 3254719 (12.42 MB)
# Non-trainable params: 26320 (102.81 KB)
# _________________________________________________________________

# %%
base_model = InceptionV3(include_top= False , weights= "imagenet", input_shape= img_shape, pooling= 'max')
inception = Sequential([
    base_model,
    Flatten(),
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(128, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])
inception.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', 
              metrics= ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

inception.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  batch_normalization_101 (B  (None, 2048)              8192
#  atchNormalization)
#
#  dense_9 (Dense)             (None, 256)               524544
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 15)                1935
#
# =================================================================
# Total params: 22370351 (85.34 MB)
# Trainable params: 22331823 (85.19 MB)
# Non-trainable params: 38528 (150.50 KB)
# _________________________________________________________________

# %%
base_model = VGG19(include_top= False , weights= "imagenet", input_shape= img_shape, pooling= 'max')
vgg = Sequential([
    base_model,
    Flatten(),
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(128, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),    
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])
vgg.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', 
              metrics= ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])

vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 512)               20024384
#
#  flatten_4 (Flatten)         (None, 512)               0
#
#  batch_normalization_102 (B  (None, 512)               2048
#  atchNormalization)
#
#  dense_12 (Dense)            (None, 256)               131328
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 15)                1935
#
# =================================================================
# Total params: 20192591 (77.03 MB)
# Trainable params: 20191567 (77.02 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
densenet_base = DenseNet201(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')
densenet_base.trainable = False  # Freeze DenseNet
efficientnet_base = EfficientNetB0(include_top=False, weights='imagenet', input_shape=img_shape, pooling='max')
efficientnet_base.trainable = False  # Freeze EfficientNet

input_tensor = layers.Input(shape=img_shape)
densenet_output = densenet_base(input_tensor)
efficientnet_output = efficientnet_base(input_tensor)
concatenated = layers.Concatenate()([densenet_output, efficientnet_output])

x = layers.Flatten()(concatenated)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, kernel_regularizer=regularizers.l2(0.016), activity_regularizer=regularizers.l1(0.006),
                 bias_regularizer=regularizers.l1(0.006), activation='relu')(x)
x = layers.Dropout(rate=0.45, seed=123)(x)
x = layers.Dense(128, kernel_regularizer=regularizers.l2(0.016), activity_regularizer=regularizers.l1(0.006),
                 bias_regularizer=regularizers.l1(0.006), activation='relu')(x)
x = layers.Dropout(rate=0.45, seed=123)(x)
output_tensor = layers.Dense(class_count, activation='softmax')(x)


denseEfficient = models.Model(inputs=input_tensor, outputs=output_tensor)
denseEfficient.compile(optimizer=tf.keras.optimizers.Adamax(learning_rate=0.001), loss='categorical_crossentropy', 
          metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
denseEfficient.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  densenet201 (Functional)    (None, 1920)                 1832198   ['input_8[0][0]']
#                                                           4
#
#  efficientnetb0 (Functional  (None, 1280)                 4049571   ['input_8[0][0]']
#  )
#
#  concatenate_2 (Concatenate  (None, 3200)                 0         ['densenet201[0][0]',
#  )                                                                   'efficientnetb0[0][0]']
#
#  flatten_5 (Flatten)         (None, 3200)                 0         ['concatenate_2[0][0]']
#
#  batch_normalization_103 (B  (None, 3200)                 12800     ['flatten_5[0][0]']
#  atchNormalization)
#
#  dense_15 (Dense)            (None, 256)                  819456    ['batch_normalization_103[0][0
#                                                                     ]']
#
#  dropout_10 (Dropout)        (None, 256)                  0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 128)                  32896     ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 128)                  0         ['dense_16[0][0]']
#
#  dense_17 (Dense)            (None, 15)                   1935      ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 23238642 (88.65 MB)
# Trainable params: 860687 (3.28 MB)
# Non-trainable params: 22377955 (85.37 MB)
# __________________________________________________________________________________________________

# %%
hist= denseEfficient.fit(train_gen, epochs= 20, verbose= 1, validation_data= valid_gen, shuffle= False )
# Out:
# Epoch 1/20
# 2025-03-03 15:41:22.780087: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/efficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741016488.537346      71 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 112/112 [==============================] - 72s 460ms/step - loss: 11.2194 - accuracy: 0.3311 - precision_5: 0.5583 - recall_5: 0.1189 - auc_5: 0.7886 - val_loss: 9.3721 - val_accuracy: 0.6071 - val_precision_5: 0.9333 - val_recall_5: 0.2188 - val_auc_5: 0.9287
# Epoch 2/20
# 112/112 [==============================] - 17s 148ms/step - loss: 8.6821 - accuracy: 0.5489 - precision_5: 0.8409 - recall_5: 0.2641 - auc_5: 0.9083 - val_loss: 7.6820 - val_accuracy: 0.6920 - val_precision_5: 0.9383 - val_recall_5: 0.3393 - val_auc_5: 0.9606
# Epoch 3/20
# 112/112 [==============================] - 17s 147ms/step - loss: 7.2922 - accuracy: 0.6326 - precision_5: 0.8863 - recall_5: 0.3417 - auc_5: 0.9407 - val_loss: 6.4486 - val_accuracy: 0.7522 - val_precision_5: 0.9679 - val_recall_5: 0.4710 - val_auc_5: 0.9760
# Epoch 4/20
# 112/112 [==============================] - 17s 148ms/step - loss: 6.1598 - accuracy: 0.7038 - precision_5: 0.9232 - recall_5: 0.4428 - auc_5: 0.9602 - val_loss: 5.4654 - val_accuracy: 0.7835 - val_precision_5: 0.9675 - val_recall_5: 0.5312 - val_auc_5: 0.9836
# Epoch 5/20
# 112/112 [==============================] - 16s 146ms/step - loss: 5.2169 - accuracy: 0.7482 - precision_5: 0.9427 - recall_5: 0.5008 - auc_5: 0.9737 - val_loss: 4.6678 - val_accuracy: 0.7879 - val_precision_5: 0.9474 - val_recall_5: 0.6027 - val_auc_5: 0.9864
# Epoch 6/20
# 112/112 [==============================] - 17s 149ms/step - loss: 4.4394 - accuracy: 0.7984 - precision_5: 0.9500 - recall_5: 0.5734 - auc_5: 0.9814 - val_loss: 3.9879 - val_accuracy: 0.8259 - val_precision_5: 0.9703 - val_recall_5: 0.6562 - val_auc_5: 0.9894
# Epoch 7/20
# 112/112 [==============================] - 17s 148ms/step - loss: 3.8276 - accuracy: 0.8255 - precision_5: 0.9497 - recall_5: 0.6008 - auc_5: 0.9854 - val_loss: 3.4226 - val_accuracy: 0.8438 - val_precision_5: 0.9469 - val_recall_5: 0.7165 - val_auc_5: 0.9919
# Epoch 8/20
# 112/112 [==============================] - 17s 147ms/step - loss: 3.2926 - accuracy: 0.8509 - precision_5: 0.9637 - recall_5: 0.6449 - auc_5: 0.9894 - val_loss: 2.9582 - val_accuracy: 0.8839 - val_precision_5: 0.9730 - val_recall_5: 0.7232 - val_auc_5: 0.9936
# Epoch 9/20
# 112/112 [==============================] - 17s 147ms/step - loss: 2.8461 - accuracy: 0.8800 - precision_5: 0.9719 - recall_5: 0.6845 - auc_5: 0.9931 - val_loss: 2.5810 - val_accuracy: 0.8772 - val_precision_5: 0.9629 - val_recall_5: 0.7522 - val_auc_5: 0.9947
# Epoch 10/20
# 112/112 [==============================] - 16s 146ms/step - loss: 2.5047 - accuracy: 0.8959 - precision_5: 0.9687 - recall_5: 0.7166 - auc_5: 0.9943 - val_loss: 2.2852 - val_accuracy: 0.8929 - val_precision_5: 0.9747 - val_recall_5: 0.7746 - val_auc_5: 0.9953
# Epoch 11/20
# 112/112 [==============================] - 16s 146ms/step - loss: 2.1780 - accuracy: 0.9109 - precision_5: 0.9814 - recall_5: 0.7647 - auc_5: 0.9966 - val_loss: 2.0150 - val_accuracy: 0.9129 - val_precision_5: 0.9806 - val_recall_5: 0.7902 - val_auc_5: 0.9965
# Epoch 12/20
# 112/112 [==============================] - 17s 147ms/step - loss: 1.9484 - accuracy: 0.9257 - precision_5: 0.9813 - recall_5: 0.7764 - auc_5: 0.9973 - val_loss: 1.8127 - val_accuracy: 0.9286 - val_precision_5: 0.9657 - val_recall_5: 0.8170 - val_auc_5: 0.9965
# Epoch 13/20
# 112/112 [==============================] - 16s 145ms/step - loss: 1.7599 - accuracy: 0.9352 - precision_5: 0.9814 - recall_5: 0.7940 - auc_5: 0.9976 - val_loss: 1.6476 - val_accuracy: 0.9152 - val_precision_5: 0.9686 - val_recall_5: 0.8259 - val_auc_5: 0.9974
# Epoch 14/20
# 112/112 [==============================] - 17s 147ms/step - loss: 1.6090 - accuracy: 0.9417 - precision_5: 0.9850 - recall_5: 0.8074 - auc_5: 0.9979 - val_loss: 1.5218 - val_accuracy: 0.9174 - val_precision_5: 0.9668 - val_recall_5: 0.8438 - val_auc_5: 0.9970
# Epoch 15/20
# 112/112 [==============================] - 16s 146ms/step - loss: 1.4781 - accuracy: 0.9514 - precision_5: 0.9840 - recall_5: 0.8241 - auc_5: 0.9984 - val_loss: 1.4314 - val_accuracy: 0.9263 - val_precision_5: 0.9663 - val_recall_5: 0.8326 - val_auc_5: 0.9973
# Epoch 16/20
# 112/112 [==============================] - 16s 146ms/step - loss: 1.3665 - accuracy: 0.9587 - precision_5: 0.9902 - recall_5: 0.8423 - auc_5: 0.9990 - val_loss: 1.3468 - val_accuracy: 0.9308 - val_precision_5: 0.9611 - val_recall_5: 0.8281 - val_auc_5: 0.9972
# Epoch 17/20
# 112/112 [==============================] - 17s 147ms/step - loss: 1.2730 - accuracy: 0.9578 - precision_5: 0.9869 - recall_5: 0.8593 - auc_5: 0.9990 - val_loss: 1.2655 - val_accuracy: 0.9353 - val_precision_5: 0.9692 - val_recall_5: 0.8438 - val_auc_5: 0.9975
# Epoch 18/20
# 112/112 [==============================] - 16s 146ms/step - loss: 1.2177 - accuracy: 0.9564 - precision_5: 0.9878 - recall_5: 0.8585 - auc_5: 0.9990 - val_loss: 1.2304 - val_accuracy: 0.9152 - val_precision_5: 0.9714 - val_recall_5: 0.8348 - val_auc_5: 0.9973
# Epoch 19/20
# 112/112 [==============================] - 16s 146ms/step - loss: 1.1619 - accuracy: 0.9601 - precision_5: 0.9861 - recall_5: 0.8696 - auc_5: 0.9989 - val_loss: 1.1649 - val_accuracy: 0.9241 - val_precision_5: 0.9647 - val_recall_5: 0.8549 - val_auc_5: 0.9965
# Epoch 20/20
# 112/112 [==============================] - 17s 146ms/step - loss: 1.1023 - accuracy: 0.9626 - precision_5: 0.9880 - recall_5: 0.8733 - auc_5: 0.9994 - val_loss: 1.1087 - val_accuracy: 0.9353 - val_precision_5: 0.9800 - val_recall_5: 0.8772 - val_auc_5: 0.9978

# %%
hist_densenet= densent.fit(train_gen, epochs= 20, verbose= 1, validation_data= valid_gen, shuffle= False )
# Out:
# Epoch 1/20
# 112/112 [==============================] - 142s 454ms/step - loss: 9.4177 - accuracy: 0.3841 - precision: 0.7410 - recall: 0.1494 - auc: 0.8083 - val_loss: 9.6682 - val_accuracy: 0.3549 - val_precision: 0.3918 - val_recall: 0.3192 - val_auc: 0.8144
# Epoch 2/20
# 112/112 [==============================] - 35s 313ms/step - loss: 6.5715 - accuracy: 0.6750 - precision: 0.9088 - recall: 0.4425 - auc: 0.9468 - val_loss: 6.1550 - val_accuracy: 0.6786 - val_precision: 0.7864 - val_recall: 0.5670 - val_auc: 0.9510
# Epoch 3/20
# 112/112 [==============================] - 35s 313ms/step - loss: 5.2202 - accuracy: 0.8090 - precision: 0.9543 - recall: 0.6301 - auc: 0.9800 - val_loss: 4.7726 - val_accuracy: 0.7857 - val_precision: 0.9500 - val_recall: 0.6362 - val_auc: 0.9853
# Epoch 4/20
# 112/112 [==============================] - 35s 314ms/step - loss: 4.2281 - accuracy: 0.8811 - precision: 0.9779 - recall: 0.7401 - auc: 0.9924 - val_loss: 3.9007 - val_accuracy: 0.8527 - val_precision: 0.9405 - val_recall: 0.7054 - val_auc: 0.9891
# Epoch 5/20
# 112/112 [==============================] - 35s 313ms/step - loss: 3.4165 - accuracy: 0.9458 - precision: 0.9895 - recall: 0.8169 - auc: 0.9978 - val_loss: 3.1431 - val_accuracy: 0.8929 - val_precision: 0.9755 - val_recall: 0.7991 - val_auc: 0.9946
# Epoch 6/20
# 112/112 [==============================] - 35s 312ms/step - loss: 2.7526 - accuracy: 0.9721 - precision: 0.9959 - recall: 0.8911 - auc: 0.9992 - val_loss: 2.4681 - val_accuracy: 0.9531 - val_precision: 0.9804 - val_recall: 0.8929 - val_auc: 0.9985
# Epoch 7/20
# 112/112 [==============================] - 35s 312ms/step - loss: 2.2193 - accuracy: 0.9913 - precision: 0.9988 - recall: 0.9366 - auc: 0.9999 - val_loss: 2.0238 - val_accuracy: 0.9576 - val_precision: 0.9810 - val_recall: 0.9219 - val_auc: 0.9969
# Epoch 8/20
# 112/112 [==============================] - 35s 313ms/step - loss: 1.8118 - accuracy: 0.9961 - precision: 1.0000 - recall: 0.9484 - auc: 1.0000 - val_loss: 1.6278 - val_accuracy: 0.9777 - val_precision: 0.9953 - val_recall: 0.9464 - val_auc: 0.9992
# Epoch 9/20
# 112/112 [==============================] - 35s 312ms/step - loss: 1.5161 - accuracy: 0.9925 - precision: 0.9968 - recall: 0.9450 - auc: 0.9998 - val_loss: 1.4887 - val_accuracy: 0.9308 - val_precision: 0.9658 - val_recall: 0.8817 - val_auc: 0.9967
# Epoch 10/20
# 112/112 [==============================] - 35s 312ms/step - loss: 1.3023 - accuracy: 0.9874 - precision: 0.9938 - recall: 0.9333 - auc: 0.9994 - val_loss: 1.4347 - val_accuracy: 0.8996 - val_precision: 0.9595 - val_recall: 0.7924 - val_auc: 0.9932
# Epoch 11/20
# 112/112 [==============================] - 35s 313ms/step - loss: 1.1252 - accuracy: 0.9863 - precision: 0.9938 - recall: 0.9394 - auc: 0.9992 - val_loss: 1.3481 - val_accuracy: 0.8683 - val_precision: 0.9146 - val_recall: 0.8125 - val_auc: 0.9866
# Epoch 12/20
# 112/112 [==============================] - 35s 312ms/step - loss: 0.9650 - accuracy: 0.9899 - precision: 0.9956 - recall: 0.9500 - auc: 0.9997 - val_loss: 0.9993 - val_accuracy: 0.9509 - val_precision: 0.9737 - val_recall: 0.9107 - val_auc: 0.9955
# Epoch 13/20
# 112/112 [==============================] - 35s 314ms/step - loss: 0.8607 - accuracy: 0.9905 - precision: 0.9959 - recall: 0.9539 - auc: 0.9997 - val_loss: 0.8403 - val_accuracy: 0.9710 - val_precision: 0.9834 - val_recall: 0.9263 - val_auc: 0.9987
# Epoch 14/20
# 112/112 [==============================] - 35s 313ms/step - loss: 0.8013 - accuracy: 0.9858 - precision: 0.9915 - recall: 0.9472 - auc: 0.9992 - val_loss: 0.9373 - val_accuracy: 0.9129 - val_precision: 0.9509 - val_recall: 0.8638 - val_auc: 0.9924
# Epoch 15/20
# 112/112 [==============================] - 35s 312ms/step - loss: 0.6882 - accuracy: 0.9961 - precision: 0.9986 - recall: 0.9721 - auc: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.9710 - val_precision: 0.9839 - val_recall: 0.9531 - val_auc: 0.9992
# Epoch 16/20
# 112/112 [==============================] - 35s 313ms/step - loss: 0.6200 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9827 - auc: 1.0000 - val_loss: 0.5886 - val_accuracy: 0.9754 - val_precision: 0.9909 - val_recall: 0.9688 - val_auc: 0.9997
# Epoch 17/20
# 112/112 [==============================] - 35s 313ms/step - loss: 0.5751 - accuracy: 0.9997 - precision: 1.0000 - recall: 0.9824 - auc: 1.0000 - val_loss: 0.5677 - val_accuracy: 0.9710 - val_precision: 0.9840 - val_recall: 0.9598 - val_auc: 0.9997
# Epoch 18/20
# 112/112 [==============================] - 35s 311ms/step - loss: 0.5460 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9824 - auc: 1.0000 - val_loss: 0.5234 - val_accuracy: 0.9844 - val_precision: 0.9910 - val_recall: 0.9844 - val_auc: 0.9987
# Epoch 19/20
# 112/112 [==============================] - 35s 313ms/step - loss: 0.5196 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9819 - auc: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.9799 - val_precision: 0.9887 - val_recall: 0.9799 - val_auc: 0.9998
# Epoch 20/20
# 112/112 [==============================] - 35s 311ms/step - loss: 0.5142 - accuracy: 0.9978 - precision: 0.9986 - recall: 0.9754 - auc: 0.9998 - val_loss: 0.7812 - val_accuracy: 0.9085 - val_precision: 0.9469 - val_recall: 0.8750 - val_auc: 0.9885

# %%
hist_inception= inception.fit(train_gen, epochs= 20, verbose= 1, validation_data= valid_gen, shuffle= False )
# Out:
# Epoch 1/20
# 112/112 [==============================] - 56s 222ms/step - loss: 12.4796 - accuracy: 0.2973 - precision_3: 0.4582 - recall_3: 0.0826 - auc_3: 0.7490 - val_loss: 12.4769 - val_accuracy: 0.2746 - val_precision_3: 0.5031 - val_recall_3: 0.1830 - val_auc_3: 0.7625
# Epoch 2/20
# 112/112 [==============================] - 18s 160ms/step - loss: 10.1264 - accuracy: 0.5567 - precision_3: 0.8531 - recall_3: 0.2870 - auc_3: 0.8877 - val_loss: 9.4400 - val_accuracy: 0.6339 - val_precision_3: 0.9032 - val_recall_3: 0.3750 - val_auc_3: 0.9304
# Epoch 3/20
# 112/112 [==============================] - 18s 161ms/step - loss: 8.6558 - accuracy: 0.6884 - precision_3: 0.9099 - recall_3: 0.4626 - auc_3: 0.9415 - val_loss: 7.9236 - val_accuracy: 0.7433 - val_precision_3: 0.9697 - val_recall_3: 0.5000 - val_auc_3: 0.9759
# Epoch 4/20
# 112/112 [==============================] - 18s 162ms/step - loss: 7.4329 - accuracy: 0.7820 - precision_3: 0.9536 - recall_3: 0.5972 - auc_3: 0.9718 - val_loss: 6.7757 - val_accuracy: 0.8281 - val_precision_3: 0.9704 - val_recall_3: 0.6585 - val_auc_3: 0.9855
# Epoch 5/20
# 112/112 [==============================] - 18s 162ms/step - loss: 6.4034 - accuracy: 0.8559 - precision_3: 0.9731 - recall_3: 0.6960 - auc_3: 0.9863 - val_loss: 5.9275 - val_accuracy: 0.8594 - val_precision_3: 0.9645 - val_recall_3: 0.7277 - val_auc_3: 0.9915
# Epoch 6/20
# 112/112 [==============================] - 18s 161ms/step - loss: 5.5007 - accuracy: 0.9165 - precision_3: 0.9848 - recall_3: 0.7800 - auc_3: 0.9936 - val_loss: 5.1219 - val_accuracy: 0.8839 - val_precision_3: 0.9545 - val_recall_3: 0.7500 - val_auc_3: 0.9930
# Epoch 7/20
# 112/112 [==============================] - 18s 163ms/step - loss: 4.7388 - accuracy: 0.9489 - precision_3: 0.9872 - recall_3: 0.8412 - auc_3: 0.9965 - val_loss: 4.3618 - val_accuracy: 0.9286 - val_precision_3: 0.9819 - val_recall_3: 0.8482 - val_auc_3: 0.9983
# Epoch 8/20
# 112/112 [==============================] - 18s 160ms/step - loss: 4.1019 - accuracy: 0.9623 - precision_3: 0.9890 - recall_3: 0.8794 - auc_3: 0.9973 - val_loss: 3.8746 - val_accuracy: 0.9152 - val_precision_3: 0.9589 - val_recall_3: 0.8326 - val_auc_3: 0.9923
# Epoch 9/20
# 112/112 [==============================] - 18s 160ms/step - loss: 3.5623 - accuracy: 0.9707 - precision_3: 0.9910 - recall_3: 0.8883 - auc_3: 0.9983 - val_loss: 4.0436 - val_accuracy: 0.8884 - val_precision_3: 0.9343 - val_recall_3: 0.8259 - val_auc_3: 0.9753
# Epoch 10/20
# 112/112 [==============================] - 18s 161ms/step - loss: 3.1241 - accuracy: 0.9643 - precision_3: 0.9848 - recall_3: 0.8889 - auc_3: 0.9977 - val_loss: 2.9696 - val_accuracy: 0.9107 - val_precision_3: 0.9620 - val_recall_3: 0.8482 - val_auc_3: 0.9967
# Epoch 11/20
# 112/112 [==============================] - 18s 160ms/step - loss: 2.6971 - accuracy: 0.9740 - precision_3: 0.9912 - recall_3: 0.9098 - auc_3: 0.9986 - val_loss: 2.6412 - val_accuracy: 0.8929 - val_precision_3: 0.9380 - val_recall_3: 0.8438 - val_auc_3: 0.9922
# Epoch 12/20
# 112/112 [==============================] - 18s 160ms/step - loss: 2.3176 - accuracy: 0.9852 - precision_3: 0.9943 - recall_3: 0.9305 - auc_3: 0.9994 - val_loss: 2.1726 - val_accuracy: 0.9464 - val_precision_3: 0.9762 - val_recall_3: 0.9152 - val_auc_3: 0.9977
# Epoch 13/20
# 112/112 [==============================] - 18s 160ms/step - loss: 2.0341 - accuracy: 0.9849 - precision_3: 0.9937 - recall_3: 0.9263 - auc_3: 0.9994 - val_loss: 1.9973 - val_accuracy: 0.9464 - val_precision_3: 0.9761 - val_recall_3: 0.9129 - val_auc_3: 0.9966
# Epoch 14/20
# 112/112 [==============================] - 18s 161ms/step - loss: 1.7761 - accuracy: 0.9866 - precision_3: 0.9932 - recall_3: 0.9391 - auc_3: 0.9990 - val_loss: 1.6940 - val_accuracy: 0.9554 - val_precision_3: 0.9737 - val_recall_3: 0.9107 - val_auc_3: 0.9985
# Epoch 15/20
# 112/112 [==============================] - 18s 161ms/step - loss: 1.5522 - accuracy: 0.9874 - precision_3: 0.9950 - recall_3: 0.9444 - auc_3: 0.9994 - val_loss: 1.4887 - val_accuracy: 0.9509 - val_precision_3: 0.9833 - val_recall_3: 0.9174 - val_auc_3: 0.9977
# Epoch 16/20
# 112/112 [==============================] - 18s 160ms/step - loss: 1.4251 - accuracy: 0.9746 - precision_3: 0.9872 - recall_3: 0.9252 - auc_3: 0.9980 - val_loss: 1.6504 - val_accuracy: 0.8594 - val_precision_3: 0.9245 - val_recall_3: 0.7924 - val_auc_3: 0.9855
# Epoch 17/20
# 112/112 [==============================] - 18s 161ms/step - loss: 1.2646 - accuracy: 0.9779 - precision_3: 0.9899 - recall_3: 0.9333 - auc_3: 0.9986 - val_loss: 1.4313 - val_accuracy: 0.8951 - val_precision_3: 0.9327 - val_recall_3: 0.8348 - val_auc_3: 0.9864
# Epoch 18/20
# 112/112 [==============================] - 18s 160ms/step - loss: 1.1659 - accuracy: 0.9743 - precision_3: 0.9845 - recall_3: 0.9224 - auc_3: 0.9981 - val_loss: 1.2960 - val_accuracy: 0.9062 - val_precision_3: 0.9327 - val_recall_3: 0.8661 - val_auc_3: 0.9903
# Epoch 19/20
# 112/112 [==============================] - 18s 161ms/step - loss: 1.0323 - accuracy: 0.9816 - precision_3: 0.9900 - recall_3: 0.9411 - auc_3: 0.9987 - val_loss: 1.1258 - val_accuracy: 0.9420 - val_precision_3: 0.9488 - val_recall_3: 0.9107 - val_auc_3: 0.9903
# Epoch 20/20
# 112/112 [==============================] - 18s 161ms/step - loss: 0.9610 - accuracy: 0.9777 - precision_3: 0.9862 - recall_3: 0.9380 - auc_3: 0.9977 - val_loss: 1.1463 - val_accuracy: 0.9085 - val_precision_3: 0.9338 - val_recall_3: 0.8817 - val_auc_3: 0.9862

# %%
hist_mvl= mvl.fit(train_gen, epochs= 20, verbose= 1, validation_data= valid_gen, shuffle= False )
# Out:
# Epoch 1/20
# 112/112 [==============================] - 41s 152ms/step - loss: 11.4976 - accuracy: 0.3236 - precision_2: 0.5701 - recall_2: 0.1351 - auc_2: 0.7853 - val_loss: 10.8748 - val_accuracy: 0.3371 - val_precision_2: 0.5769 - val_recall_2: 0.0335 - val_auc_2: 0.7645
# Epoch 2/20
# 112/112 [==============================] - 14s 124ms/step - loss: 9.1592 - accuracy: 0.5910 - precision_2: 0.8795 - recall_2: 0.3445 - auc_2: 0.9229 - val_loss: 9.3582 - val_accuracy: 0.2991 - val_precision_2: 0.4945 - val_recall_2: 0.1004 - val_auc_2: 0.7819
# Epoch 3/20
# 112/112 [==============================] - 14s 121ms/step - loss: 7.5321 - accuracy: 0.7278 - precision_2: 0.9510 - recall_2: 0.5098 - auc_2: 0.9647 - val_loss: 8.1936 - val_accuracy: 0.2634 - val_precision_2: 0.3885 - val_recall_2: 0.1362 - val_auc_2: 0.7909
# Epoch 4/20
# 112/112 [==============================] - 14s 121ms/step - loss: 6.1899 - accuracy: 0.8236 - precision_2: 0.9694 - recall_2: 0.6360 - auc_2: 0.9844 - val_loss: 6.9026 - val_accuracy: 0.3214 - val_precision_2: 0.5812 - val_recall_2: 0.1518 - val_auc_2: 0.8405
# Epoch 5/20
# 112/112 [==============================] - 14s 121ms/step - loss: 5.0587 - accuracy: 0.8858 - precision_2: 0.9871 - recall_2: 0.7286 - auc_2: 0.9937 - val_loss: 5.9645 - val_accuracy: 0.3371 - val_precision_2: 0.5128 - val_recall_2: 0.2232 - val_auc_2: 0.8526
# Epoch 6/20
# 112/112 [==============================] - 14s 126ms/step - loss: 4.1251 - accuracy: 0.9299 - precision_2: 0.9913 - recall_2: 0.7954 - auc_2: 0.9973 - val_loss: 5.2534 - val_accuracy: 0.3259 - val_precision_2: 0.4615 - val_recall_2: 0.1741 - val_auc_2: 0.8385
# Epoch 7/20
# 112/112 [==============================] - 14s 126ms/step - loss: 3.3373 - accuracy: 0.9612 - precision_2: 0.9964 - recall_2: 0.8506 - auc_2: 0.9991 - val_loss: 4.5707 - val_accuracy: 0.3750 - val_precision_2: 0.4348 - val_recall_2: 0.2009 - val_auc_2: 0.8515
# Epoch 8/20
# 112/112 [==============================] - 14s 127ms/step - loss: 2.6986 - accuracy: 0.9821 - precision_2: 0.9978 - recall_2: 0.8914 - auc_2: 0.9997 - val_loss: 3.7941 - val_accuracy: 0.4688 - val_precision_2: 0.6257 - val_recall_2: 0.2500 - val_auc_2: 0.8882
# Epoch 9/20
# 112/112 [==============================] - 13s 119ms/step - loss: 2.1854 - accuracy: 0.9886 - precision_2: 0.9988 - recall_2: 0.9179 - auc_2: 0.9999 - val_loss: 3.1822 - val_accuracy: 0.5312 - val_precision_2: 0.7487 - val_recall_2: 0.3125 - val_auc_2: 0.9141
# Epoch 10/20
# 112/112 [==============================] - 14s 120ms/step - loss: 1.7849 - accuracy: 0.9947 - precision_2: 0.9991 - recall_2: 0.9283 - auc_2: 0.9999 - val_loss: 2.8364 - val_accuracy: 0.5379 - val_precision_2: 0.7302 - val_recall_2: 0.3080 - val_auc_2: 0.9143
# Epoch 11/20
# 112/112 [==============================] - 14s 122ms/step - loss: 1.4675 - accuracy: 0.9964 - precision_2: 0.9994 - recall_2: 0.9458 - auc_2: 0.9999 - val_loss: 2.4057 - val_accuracy: 0.6272 - val_precision_2: 0.8708 - val_recall_2: 0.3460 - val_auc_2: 0.9383
# Epoch 12/20
# 112/112 [==============================] - 14s 122ms/step - loss: 1.2260 - accuracy: 0.9966 - precision_2: 0.9997 - recall_2: 0.9531 - auc_2: 1.0000 - val_loss: 2.2451 - val_accuracy: 0.5960 - val_precision_2: 0.7489 - val_recall_2: 0.3862 - val_auc_2: 0.9254
# Epoch 13/20
# 112/112 [==============================] - 13s 120ms/step - loss: 1.0399 - accuracy: 0.9972 - precision_2: 0.9991 - recall_2: 0.9626 - auc_2: 1.0000 - val_loss: 2.0609 - val_accuracy: 0.6094 - val_precision_2: 0.7893 - val_recall_2: 0.4263 - val_auc_2: 0.9318
# Epoch 14/20
# 112/112 [==============================] - 13s 119ms/step - loss: 0.8994 - accuracy: 0.9994 - precision_2: 1.0000 - recall_2: 0.9685 - auc_2: 1.0000 - val_loss: 1.7583 - val_accuracy: 0.6830 - val_precision_2: 0.8615 - val_recall_2: 0.4442 - val_auc_2: 0.9583
# Epoch 15/20
# 112/112 [==============================] - 14s 125ms/step - loss: 0.7962 - accuracy: 0.9975 - precision_2: 0.9988 - recall_2: 0.9668 - auc_2: 1.0000 - val_loss: 1.6389 - val_accuracy: 0.6987 - val_precision_2: 0.8902 - val_recall_2: 0.5067 - val_auc_2: 0.9554
# Epoch 16/20
# 112/112 [==============================] - 14s 123ms/step - loss: 0.7243 - accuracy: 0.9980 - precision_2: 0.9991 - recall_2: 0.9665 - auc_2: 1.0000 - val_loss: 1.5211 - val_accuracy: 0.7210 - val_precision_2: 0.8813 - val_recall_2: 0.5469 - val_auc_2: 0.9621
# Epoch 17/20
# 112/112 [==============================] - 14s 122ms/step - loss: 0.6560 - accuracy: 0.9994 - precision_2: 1.0000 - recall_2: 0.9743 - auc_2: 1.0000 - val_loss: 1.5498 - val_accuracy: 0.6853 - val_precision_2: 0.8736 - val_recall_2: 0.5246 - val_auc_2: 0.9495
# Epoch 18/20
# 112/112 [==============================] - 14s 121ms/step - loss: 0.6170 - accuracy: 0.9978 - precision_2: 0.9994 - recall_2: 0.9715 - auc_2: 1.0000 - val_loss: 1.4834 - val_accuracy: 0.6964 - val_precision_2: 0.8262 - val_recall_2: 0.5625 - val_auc_2: 0.9585
# Epoch 19/20
# 112/112 [==============================] - 14s 124ms/step - loss: 0.5854 - accuracy: 0.9980 - precision_2: 0.9986 - recall_2: 0.9707 - auc_2: 1.0000 - val_loss: 1.4820 - val_accuracy: 0.6853 - val_precision_2: 0.8691 - val_recall_2: 0.5335 - val_auc_2: 0.9496
# Epoch 20/20
# 112/112 [==============================] - 14s 125ms/step - loss: 0.5477 - accuracy: 0.9997 - precision_2: 1.0000 - recall_2: 0.9777 - auc_2: 1.0000 - val_loss: 1.3521 - val_accuracy: 0.7210 - val_precision_2: 0.8730 - val_recall_2: 0.5982 - val_auc_2: 0.9593

# %%
hist_xception= xcept.fit(train_gen, epochs= 20, verbose= 1, validation_data= valid_gen, shuffle= False )
# Out:
# Epoch 1/20
# 112/112 [==============================] - 62s 334ms/step - loss: 12.0085 - accuracy: 0.3730 - precision_1: 0.6841 - recall_1: 0.1281 - auc_1: 0.7830 - val_loss: 11.1187 - val_accuracy: 0.2991 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.7191
# Epoch 2/20
# 112/112 [==============================] - 31s 273ms/step - loss: 9.3752 - accuracy: 0.6678 - precision_1: 0.9451 - recall_1: 0.4277 - auc_1: 0.9421 - val_loss: 9.5836 - val_accuracy: 0.2991 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.7958
# Epoch 3/20
# 112/112 [==============================] - 31s 274ms/step - loss: 7.6570 - accuracy: 0.7956 - precision_1: 0.9762 - recall_1: 0.6192 - auc_1: 0.9787 - val_loss: 7.8335 - val_accuracy: 0.7790 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_1: 0.9521
# Epoch 4/20
# 112/112 [==============================] - 31s 273ms/step - loss: 6.2390 - accuracy: 0.8802 - precision_1: 0.9868 - recall_1: 0.7323 - auc_1: 0.9930 - val_loss: 6.3272 - val_accuracy: 0.8705 - val_precision_1: 1.0000 - val_recall_1: 0.0246 - val_auc_1: 0.9827
# Epoch 5/20
# 112/112 [==============================] - 31s 272ms/step - loss: 5.0394 - accuracy: 0.9503 - precision_1: 0.9940 - recall_1: 0.8289 - auc_1: 0.9980 - val_loss: 4.7769 - val_accuracy: 0.9353 - val_precision_1: 0.9962 - val_recall_1: 0.5826 - val_auc_1: 0.9968
# Epoch 6/20
# 112/112 [==============================] - 31s 274ms/step - loss: 4.0520 - accuracy: 0.9788 - precision_1: 0.9969 - recall_1: 0.9028 - auc_1: 0.9995 - val_loss: 3.7033 - val_accuracy: 0.9554 - val_precision_1: 0.9919 - val_recall_1: 0.8214 - val_auc_1: 0.9988
# Epoch 7/20
# 112/112 [==============================] - 31s 273ms/step - loss: 3.2544 - accuracy: 0.9933 - precision_1: 0.9991 - recall_1: 0.9363 - auc_1: 0.9999 - val_loss: 2.9397 - val_accuracy: 0.9598 - val_precision_1: 0.9853 - val_recall_1: 0.8996 - val_auc_1: 0.9989
# Epoch 8/20
# 112/112 [==============================] - 31s 273ms/step - loss: 2.6182 - accuracy: 0.9969 - precision_1: 1.0000 - recall_1: 0.9570 - auc_1: 1.0000 - val_loss: 2.3688 - val_accuracy: 0.9710 - val_precision_1: 0.9881 - val_recall_1: 0.9241 - val_auc_1: 0.9982
# Epoch 9/20
# 112/112 [==============================] - 31s 274ms/step - loss: 2.1205 - accuracy: 0.9994 - precision_1: 0.9997 - recall_1: 0.9640 - auc_1: 1.0000 - val_loss: 1.9468 - val_accuracy: 0.9688 - val_precision_1: 0.9833 - val_recall_1: 0.9219 - val_auc_1: 0.9991
# Epoch 10/20
# 112/112 [==============================] - 31s 274ms/step - loss: 1.7248 - accuracy: 0.9997 - precision_1: 1.0000 - recall_1: 0.9679 - auc_1: 1.0000 - val_loss: 1.5740 - val_accuracy: 0.9710 - val_precision_1: 0.9884 - val_recall_1: 0.9509 - val_auc_1: 0.9991
# Epoch 11/20
# 112/112 [==============================] - 31s 274ms/step - loss: 1.4168 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 0.9729 - auc_1: 1.0000 - val_loss: 1.3170 - val_accuracy: 0.9754 - val_precision_1: 0.9906 - val_recall_1: 0.9420 - val_auc_1: 0.9987
# Epoch 12/20
# 112/112 [==============================] - 31s 274ms/step - loss: 1.1974 - accuracy: 0.9986 - precision_1: 0.9997 - recall_1: 0.9665 - auc_1: 1.0000 - val_loss: 1.1523 - val_accuracy: 0.9598 - val_precision_1: 0.9791 - val_recall_1: 0.9397 - val_auc_1: 0.9990
# Epoch 13/20
# 112/112 [==============================] - 31s 274ms/step - loss: 1.0271 - accuracy: 0.9978 - precision_1: 1.0000 - recall_1: 0.9693 - auc_1: 1.0000 - val_loss: 0.9982 - val_accuracy: 0.9710 - val_precision_1: 0.9793 - val_recall_1: 0.9509 - val_auc_1: 0.9964
# Epoch 14/20
# 112/112 [==============================] - 31s 274ms/step - loss: 0.9435 - accuracy: 0.9894 - precision_1: 0.9942 - recall_1: 0.9534 - auc_1: 0.9996 - val_loss: 0.9126 - val_accuracy: 0.9554 - val_precision_1: 0.9835 - val_recall_1: 0.9308 - val_auc_1: 0.9988
# Epoch 15/20
# 112/112 [==============================] - 31s 273ms/step - loss: 0.8233 - accuracy: 0.9939 - precision_1: 0.9963 - recall_1: 0.9693 - auc_1: 0.9999 - val_loss: 0.8599 - val_accuracy: 0.9621 - val_precision_1: 0.9764 - val_recall_1: 0.9219 - val_auc_1: 0.9973
# Epoch 16/20
# 112/112 [==============================] - 31s 274ms/step - loss: 0.7469 - accuracy: 0.9939 - precision_1: 0.9966 - recall_1: 0.9690 - auc_1: 0.9998 - val_loss: 0.7892 - val_accuracy: 0.9487 - val_precision_1: 0.9718 - val_recall_1: 0.9219 - val_auc_1: 0.9981
# Epoch 17/20
# 112/112 [==============================] - 31s 274ms/step - loss: 0.6744 - accuracy: 0.9975 - precision_1: 0.9994 - recall_1: 0.9752 - auc_1: 1.0000 - val_loss: 0.6627 - val_accuracy: 0.9710 - val_precision_1: 0.9861 - val_recall_1: 0.9509 - val_auc_1: 0.9992
# Epoch 18/20
# 112/112 [==============================] - 31s 274ms/step - loss: 0.6223 - accuracy: 0.9986 - precision_1: 0.9997 - recall_1: 0.9771 - auc_1: 1.0000 - val_loss: 0.6368 - val_accuracy: 0.9777 - val_precision_1: 0.9817 - val_recall_1: 0.9554 - val_auc_1: 0.9985
# Epoch 19/20
# 112/112 [==============================] - 31s 273ms/step - loss: 0.5820 - accuracy: 0.9989 - precision_1: 0.9991 - recall_1: 0.9796 - auc_1: 1.0000 - val_loss: 0.6113 - val_accuracy: 0.9665 - val_precision_1: 0.9792 - val_recall_1: 0.9464 - val_auc_1: 0.9980
# Epoch 20/20
# 112/112 [==============================] - 31s 274ms/step - loss: 0.5736 - accuracy: 0.9947 - precision_1: 0.9977 - recall_1: 0.9679 - auc_1: 0.9999 - val_loss: 0.6242 - val_accuracy: 0.9576 - val_precision_1: 0.9680 - val_recall_1: 0.9442 - val_auc_1: 0.9969

# %%
hist_vgg= vgg.fit(train_gen, epochs= 20, verbose= 1, validation_data= valid_gen, shuffle= False )
# Out:
# Epoch 1/20
# 112/112 [==============================] - 53s 345ms/step - loss: 9.6908 - accuracy: 0.2197 - precision_4: 0.2292 - recall_4: 0.0031 - auc_4: 0.6926 - val_loss: 12.6530 - val_accuracy: 0.2299 - val_precision_4: 0.3080 - val_recall_4: 0.1808 - val_auc_4: 0.7107
# Epoch 2/20
# 112/112 [==============================] - 29s 261ms/step - loss: 7.5555 - accuracy: 0.2884 - precision_4: 0.4091 - recall_4: 0.0050 - auc_4: 0.7688 - val_loss: 7.0452 - val_accuracy: 0.3036 - val_precision_4: 0.3922 - val_recall_4: 0.0446 - val_auc_4: 0.7711
# Epoch 3/20
# 112/112 [==============================] - 29s 261ms/step - loss: 6.2502 - accuracy: 0.3322 - precision_4: 0.4818 - recall_4: 0.0148 - auc_4: 0.7915 - val_loss: 5.7917 - val_accuracy: 0.3371 - val_precision_4: 0.5714 - val_recall_4: 0.0089 - val_auc_4: 0.8032
# Epoch 4/20
# 112/112 [==============================] - 29s 260ms/step - loss: 5.2529 - accuracy: 0.3760 - precision_4: 0.6562 - recall_4: 0.0469 - auc_4: 0.8183 - val_loss: 5.0174 - val_accuracy: 0.3036 - val_precision_4: 0.6667 - val_recall_4: 0.0446 - val_auc_4: 0.7973
# Epoch 5/20
# 112/112 [==============================] - 29s 262ms/step - loss: 4.4924 - accuracy: 0.4045 - precision_4: 0.6984 - recall_4: 0.0717 - auc_4: 0.8382 - val_loss: 4.3592 - val_accuracy: 0.3549 - val_precision_4: 0.5303 - val_recall_4: 0.0781 - val_auc_4: 0.8213
# Epoch 6/20
# 112/112 [==============================] - 29s 261ms/step - loss: 3.9052 - accuracy: 0.4296 - precision_4: 0.7361 - recall_4: 0.1036 - auc_4: 0.8506 - val_loss: 3.9994 - val_accuracy: 0.3281 - val_precision_4: 0.4615 - val_recall_4: 0.0134 - val_auc_4: 0.8023
# Epoch 7/20
# 112/112 [==============================] - 29s 261ms/step - loss: 3.4597 - accuracy: 0.4433 - precision_4: 0.7524 - recall_4: 0.1298 - auc_4: 0.8603 - val_loss: 3.3849 - val_accuracy: 0.4196 - val_precision_4: 0.7143 - val_recall_4: 0.1451 - val_auc_4: 0.8513
# Epoch 8/20
# 112/112 [==============================] - 29s 261ms/step - loss: 3.0850 - accuracy: 0.4771 - precision_4: 0.7798 - recall_4: 0.1681 - auc_4: 0.8713 - val_loss: 3.0169 - val_accuracy: 0.4777 - val_precision_4: 0.8036 - val_recall_4: 0.1004 - val_auc_4: 0.8754
# Epoch 9/20
# 112/112 [==============================] - 29s 261ms/step - loss: 2.7810 - accuracy: 0.5011 - precision_4: 0.8177 - recall_4: 0.2091 - auc_4: 0.8843 - val_loss: 2.6694 - val_accuracy: 0.5446 - val_precision_4: 0.8772 - val_recall_4: 0.2232 - val_auc_4: 0.8974
# Epoch 10/20
# 112/112 [==============================] - 29s 260ms/step - loss: 2.5840 - accuracy: 0.5098 - precision_4: 0.8306 - recall_4: 0.2286 - auc_4: 0.8881 - val_loss: 2.9794 - val_accuracy: 0.3348 - val_precision_4: 0.9444 - val_recall_4: 0.0379 - val_auc_4: 0.8166
# Epoch 11/20
# 112/112 [==============================] - 29s 260ms/step - loss: 2.3534 - accuracy: 0.5338 - precision_4: 0.8505 - recall_4: 0.2889 - auc_4: 0.9032 - val_loss: 61.7449 - val_accuracy: 0.5290 - val_precision_4: 0.6364 - val_recall_4: 0.3906 - val_auc_4: 0.8776
# Epoch 12/20
# 112/112 [==============================] - 29s 261ms/step - loss: 2.2380 - accuracy: 0.5458 - precision_4: 0.8442 - recall_4: 0.2951 - auc_4: 0.9068 - val_loss: 4.6389 - val_accuracy: 0.4799 - val_precision_4: 0.7582 - val_recall_4: 0.3080 - val_auc_4: 0.8870
# Epoch 13/20
# 112/112 [==============================] - 29s 262ms/step - loss: 2.0979 - accuracy: 0.5698 - precision_4: 0.8484 - recall_4: 0.3328 - auc_4: 0.9159 - val_loss: 2.3177 - val_accuracy: 0.4866 - val_precision_4: 0.6150 - val_recall_4: 0.3103 - val_auc_4: 0.8908
# Epoch 14/20
# 112/112 [==============================] - 29s 261ms/step - loss: 1.9860 - accuracy: 0.5818 - precision_4: 0.8382 - recall_4: 0.3660 - auc_4: 0.9233 - val_loss: 2.0387 - val_accuracy: 0.5625 - val_precision_4: 0.8681 - val_recall_4: 0.3527 - val_auc_4: 0.9208
# Epoch 15/20
# 112/112 [==============================] - 29s 261ms/step - loss: 1.8729 - accuracy: 0.6092 - precision_4: 0.8622 - recall_4: 0.3981 - auc_4: 0.9329 - val_loss: 3.1941 - val_accuracy: 0.2835 - val_precision_4: 0.3283 - val_recall_4: 0.1942 - val_auc_4: 0.8304
# Epoch 16/20
# 112/112 [==============================] - 29s 260ms/step - loss: 1.8094 - accuracy: 0.6147 - precision_4: 0.8756 - recall_4: 0.4185 - auc_4: 0.9371 - val_loss: 2.0794 - val_accuracy: 0.5469 - val_precision_4: 0.9024 - val_recall_4: 0.3304 - val_auc_4: 0.9254
# Epoch 17/20
# 112/112 [==============================] - 29s 261ms/step - loss: 1.7282 - accuracy: 0.6362 - precision_4: 0.8873 - recall_4: 0.4461 - auc_4: 0.9433 - val_loss: 1.8075 - val_accuracy: 0.6272 - val_precision_4: 0.7857 - val_recall_4: 0.4420 - val_auc_4: 0.9340
# Epoch 18/20
# 112/112 [==============================] - 29s 261ms/step - loss: 1.6673 - accuracy: 0.6502 - precision_4: 0.8950 - recall_4: 0.4687 - auc_4: 0.9480 - val_loss: 1.7949 - val_accuracy: 0.6071 - val_precision_4: 0.8586 - val_recall_4: 0.3795 - val_auc_4: 0.9362
# Epoch 19/20
# 112/112 [==============================] - 29s 261ms/step - loss: 1.6063 - accuracy: 0.6714 - precision_4: 0.8939 - recall_4: 0.4941 - auc_4: 0.9511 - val_loss: 1.8240 - val_accuracy: 0.5938 - val_precision_4: 0.8115 - val_recall_4: 0.4710 - val_auc_4: 0.9309
# Epoch 20/20
# 112/112 [==============================] - 29s 262ms/step - loss: 1.5474 - accuracy: 0.6926 - precision_4: 0.8978 - recall_4: 0.5103 - auc_4: 0.9559 - val_loss: 1.5382 - val_accuracy: 0.6830 - val_precision_4: 0.8650 - val_recall_4: 0.5290 - val_auc_4: 0.9578

# %%
def plots(x):
    tr_acc = x.history['accuracy']
    tr_loss = x.history['loss']
    val_acc = x.history['val_accuracy']
    val_loss = x.history['val_loss']

    index_acc = np.argmax(val_acc) 
    index_loss = np.argmin(val_loss)

    val_lowest=val_loss[index_loss]
    acc_highest=val_acc[index_acc]

    epochs = [i+1 for i in range(len(tr_acc))]

    loss_label = f'best epoch = {str(index_loss+1)}'
    acc_label =  f'best epoch = {str(index_acc+1)} '

    plt.figure(figsize= (20,8))
    plt.style.use('fivethirtyeight')

    plt.subplot(1,2,1)
    plt.plot(epochs,val_loss,c='g',label= 'Testing Loss')
    plt.plot(epochs,tr_loss,c='r',label= 'Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Loss')

    plt.subplot(1,2,2)
    plt.plot(epochs, tr_acc, c='r', label= 'Training Accuracy')
    plt.plot(epochs, val_acc, c='g', label= 'Testing Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy')

    plt.tight_layout()
    plt.show()

# %%
print("Hybrid DenseEfficient")
plots(hist)
print("VGG19")
plots(hist_vgg)
print("Xception")
plots(hist_xception)
print("Mobilenet")
plots(hist_mvl)
print("Densenet")
plots(hist_densenet)
print("Inception")
plots(hist_inception)
# Out:
# Hybrid DenseEfficient
# VGG19
# Xception
# Mobilenet
# Densenet
# Inception

# %%
def showinfo(x):
    train_score = x.evaluate(train_gen)
    valid_score = x.evaluate(valid_gen)
    test_score =  x.evaluate(test_gen)
    print("Train Loss: ", train_score[0])
    print("Train Accuracy: ", train_score[1])
    print('-' * 30)
    print("Valid Loss: ", valid_score[0])
    print("Valid Accuracy: ", valid_score[1])
    print('-' * 30)
    print("Test Loss: ", test_score[0])
    print("Test Accuracy: ", test_score[1])

# %%
print("Hybrid DenseEfficient")
showinfo(denseEfficient)
print('-'*100)
print("Moblinet")
showinfo(mvl)
print('-'*100)
print("Inception")
showinfo(inception)
print('-'*100)
print("Xception")
showinfo(xcept)
print('-'*100)
print("Dense")
showinfo(densent)
print('-'*100)
print("VGG19")
showinfo(vgg)
# Out:
# Hybrid DenseEfficient
# 112/112 [==============================] - 15s 134ms/step - loss: 0.9118 - accuracy: 0.9964 - precision_5: 0.9980 - recall_5: 0.9872 - auc_5: 1.0000
# 14/14 [==============================] - 2s 127ms/step - loss: 1.1087 - accuracy: 0.9353 - precision_5: 0.9800 - recall_5: 0.8772 - auc_5: 0.9978
# 14/14 [==============================] - 5s 370ms/step - loss: 1.1457 - accuracy: 0.9174 - precision_5: 0.9575 - recall_5: 0.8549 - auc_5: 0.9963
# Train Loss:  0.9118260145187378
# Train Accuracy:  0.9963707327842712
# ------------------------------
# Valid Loss:  1.1086952686309814
# Valid Accuracy:  0.9352678656578064
# ------------------------------
# Test Loss:  1.1457195281982422
# Test Accuracy:  0.9174107313156128
# ----------------------------------------------------------------------------------------------------
# Moblinet
# 112/112 [==============================] - 12s 110ms/step - loss: 1.1719 - accuracy: 0.7973 - precision_2: 0.9036 - recall_2: 0.6413 - auc_2: 0.9736
# 14/14 [==============================] - 2s 108ms/step - loss: 1.3521 - accuracy: 0.7210 - precision_2: 0.8730 - recall_2: 0.5982 - auc_2: 0.9593
# 14/14 [==============================] - 2s 109ms/step - loss: 1.3918 - accuracy: 0.7121 - precision_2: 0.8562 - recall_2: 0.5848 - auc_2: 0.9536
# Train Loss:  1.1719274520874023
# Train Accuracy:  0.7973199486732483
# ------------------------------
# Valid Loss:  1.3520957231521606
# Valid Accuracy:  0.7209821343421936
# ------------------------------
# Test Loss:  1.3917664289474487
# Test Accuracy:  0.7120535969734192
# ----------------------------------------------------------------------------------------------------
# Inception
# 112/112 [==============================] - 12s 110ms/step - loss: 0.9204 - accuracy: 0.9687 - precision_3: 0.9745 - recall_3: 0.9598 - auc_3: 0.9934
# 14/14 [==============================] - 2s 107ms/step - loss: 1.1463 - accuracy: 0.9085 - precision_3: 0.9338 - recall_3: 0.8817 - auc_3: 0.9862
# 14/14 [==============================] - 2s 108ms/step - loss: 1.2688 - accuracy: 0.8906 - precision_3: 0.9155 - recall_3: 0.8460 - auc_3: 0.9747
# Train Loss:  0.9204238057136536
# Train Accuracy:  0.9687325358390808
# ------------------------------
# Valid Loss:  1.1462838649749756
# Valid Accuracy:  0.9084821343421936
# ------------------------------
# Test Loss:  1.2688087224960327
# Test Accuracy:  0.890625
# ----------------------------------------------------------------------------------------------------
# Xception
# 112/112 [==============================] - 12s 109ms/step - loss: 0.4788 - accuracy: 0.9997 - precision_1: 0.9997 - recall_1: 0.9997 - auc_1: 1.0000
# 14/14 [==============================] - 2s 108ms/step - loss: 0.6242 - accuracy: 0.9576 - precision_1: 0.9680 - recall_1: 0.9442 - auc_1: 0.9969
# 14/14 [==============================] - 2s 116ms/step - loss: 0.6923 - accuracy: 0.9330 - precision_1: 0.9643 - recall_1: 0.9040 - auc_1: 0.9926
# Train Loss:  0.4788428246974945
# Train Accuracy:  0.9997208118438721
# ------------------------------
# Valid Loss:  0.6241549253463745
# Valid Accuracy:  0.9575892686843872
# ------------------------------
# Test Loss:  0.6922716498374939
# Test Accuracy:  0.9330357313156128
# ----------------------------------------------------------------------------------------------------
# Dense
# 112/112 [==============================] - 13s 115ms/step - loss: 0.6158 - accuracy: 0.9553 - precision: 0.9710 - recall: 0.9355 - auc: 0.9959
# 14/14 [==============================] - 2s 119ms/step - loss: 0.7812 - accuracy: 0.9085 - precision: 0.9469 - recall: 0.8750 - auc: 0.9885
# 14/14 [==============================] - 2s 113ms/step - loss: 0.8333 - accuracy: 0.8973 - precision: 0.9300 - recall: 0.8594 - auc: 0.9843
# Train Loss:  0.6158285140991211
# Train Accuracy:  0.9553322196006775
# ------------------------------
# Valid Loss:  0.7811747193336487
# Valid Accuracy:  0.9084821343421936
# ------------------------------
# Test Loss:  0.8332732319831848
# Test Accuracy:  0.8973214030265808
# ----------------------------------------------------------------------------------------------------
# VGG19
# 112/112 [==============================] - 12s 105ms/step - loss: 1.4684 - accuracy: 0.7077 - precision_4: 0.9122 - recall_4: 0.5572 - auc_4: 0.9630
# 14/14 [==============================] - 2s 114ms/step - loss: 1.5382 - accuracy: 0.6830 - precision_4: 0.8650 - recall_4: 0.5290 - auc_4: 0.9578
# 14/14 [==============================] - 2s 119ms/step - loss: 1.5989 - accuracy: 0.6674 - precision_4: 0.8625 - recall_4: 0.5179 - auc_4: 0.9495
# Train Loss:  1.4683887958526611
# Train Accuracy:  0.7077051997184753
# ------------------------------
# Valid Loss:  1.538151741027832
# Valid Accuracy:  0.6830357313156128
# ------------------------------
# Test Loss:  1.5989429950714111
# Test Accuracy:  0.6674107313156128

# %%
def confuse(x):
    preds = x.predict_generator(test_gen)
    y_pred= np.argmax(preds,axis=1)
    g_dict = test_gen.class_indices
    classes = list(g_dict.keys())

    cm = confusion_matrix(test_gen.classes, y_pred)
    plt.figure(figsize= (10, 10))
    plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Reds)
    plt.title('Confusion Matrix')
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation= 45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')    
    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
print("Hybrid DenseEfficient")
confuse(denseEfficient)
print('-'*100)
print("Moblinet")
confuse(mvl)
print('-'*100)
print("Inception")
    confuse(inception)
print('-'*100)
print("Xception")
confuse(xcept)
print('-'*100)
# Out:
# Hybrid DenseEfficient
# ----------------------------------------------------------------------------------------------------
# Moblinet
# ----------------------------------------------------------------------------------------------------
# Inception
# ----------------------------------------------------------------------------------------------------
# Xception
# ----------------------------------------------------------------------------------------------------

# %%
print("Dense")
confuse(densent)
print('-'*100)
print("Vgg19")
confuse(vgg)
# Out:
# Dense
# ----------------------------------------------------------------------------------------------------
# Vgg19
